# %% [markdown]
# <a href="https://colab.research.google.com/github/CUKykkim/docker_ubuntu/blob/main/%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C_%EB%8F%84%EC%BB%A4_%EC%8B%A4%EC%8A%B5_%ED%99%98%EA%B2%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 클라우드 기반의 도커 실습 환경 가이드

# %% [markdown]
# **본 가이드는 로컬 환경에서 도커를 설치하지 못하시는 분들을 위해 작성이 되었으며, 실습환경이 타 학생과 공유가 되는 클라우드환경에서의 제약사항으로 인해 기능 동작이 원활하지 않을 수 있다는 점을 명심해 주시기 바랍니다.**

# %% [markdown]
# 1. Windows Terminal 실행
#
# 1. 아래와 같이 ssh 접속 명령어 입력
#
# ```
# ssh -p 63615 globus@211.237.9.166
# ```
#
#
#
# 3. 비밀번호 입력후 우분투 접속
#
# ![docker_cloud](./images/docker_cloud.png)

# %% [markdown]
# 4. docker 명령어 앞에 sudo 명령어를 항상 붙여서 사용 (비밀번호를 입력요구할 시 비밀번호 추가 입력)
#
# ![docker_cloud](./images/docker_cloud.png)

# %% [markdown]
# ## 클라우드 실습시 주의 사항

# %% [markdown]
# - 모든 docker 명령어 사용시 앞에 sudo 명령어를 붙일 것!!!

# %% [markdown]
# - 실습 환경을 타 학생과 공유 하므로, 실습이 끝나고 난 뒤 반드시 자신이 수행중인 컨테이너를 삭제할 것!!!!!
#
#   * 삭제 예 :  sudo docker stop f7a3c7c4728e && sudo docker rm f7a3c7c4728e
#
#   ![Cap 2021-09-19 19-06-04-203.jpg](data:image/jpeg;base64,...)
